# %% [markdown]
# # Analisis Klasifikasi Penyakit Daun Tomat
# ## Menggunakan EfficientNetV2 & Grad-CAM
#
# Notebook ini digunakan untuk menjalankan eksperimen secara interaktif.

# %%
import sys
import os
sys.path.append('../src')

from train import main as run_training

# Jalankan seluruh pipeline pelatihan
run_training()
